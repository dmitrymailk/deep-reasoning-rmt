# %%
from datasets import load_dataset

load_dataset('Salesforce/wikitext', 'wikitext-103-raw-v1')
# Out:
# ...
# Generating validation split: 100%|██████████| 3760/3760 [00:00<00:00, 1602375.84 examples/s]
# DatasetDict({
#     test: Dataset({
#         features: ['text'],
#         num_rows: 4358
#     })
#     train: Dataset({
#         features: ['text'],
#         num_rows: 1801350
#     })
#     validation: Dataset({
#         features: ['text'],
#         num_rows: 3760
#     })
# })
